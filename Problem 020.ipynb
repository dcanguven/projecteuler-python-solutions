# %% [markdown]
# ![image.png](attachment:4f1b2a67-8104-42f7-8415-1f13d680fb85.png)

# %% [markdown]
# ## Initial Approach

# %%
# %%time

product = 1
for i in range(2,101):
    product*=i

total = 0

for i in str(product):
    total += int(i)

total
# Out:
# CPU times: user 90 μs, sys: 6 μs, total: 96 μs
# Wall time: 100 μs
# 648

# %% [markdown]
# ## Clean and tested code

# %%
# %%time

import math
n = 100
print(sum(map(int, str(math.factorial(n)))))
# Out:
# 648
# CPU times: user 233 μs, sys: 78 μs, total: 311 μs
# Wall time: 284 μs
