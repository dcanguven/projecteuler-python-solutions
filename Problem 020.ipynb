# %% [markdown]
# <img src= "attachment:2379a3f8-2512-4e8b-b625-0fcec82a9ef6.png" width="700"/>

# %% [markdown]
# ## Initial Approach

# %%
# %%time

product = 1
for i in range(2,101):
    product*=i

total = 0

for i in str(product):
    total += int(i)

total
# Out:
# CPU times: user 117 μs, sys: 1 μs, total: 118 μs
# Wall time: 123 μs
# 648

# %% [markdown]
# ## Clean and tested code

# %%
# %%time

import math
n = 100
print(sum(map(int, str(math.factorial(n)))))
# Out:
# 648
# CPU times: user 313 μs, sys: 172 μs, total: 485 μs
# Wall time: 393 μs
