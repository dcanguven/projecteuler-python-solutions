# %% [markdown]
# ![image.png](attachment:3151f139-b3c7-4964-9d7b-94d332170ea6.png)

# %% [markdown]
# ## Initial Approach

# %% [markdown]
# Find a way to write the expression above.

# %%
num = 12345
num = "0."+str(num)
num = float(num)
num
# Out:
# 0.12345

# %% [markdown]
# Now try writing n digit of this number.

# %%
n=10
num = "0."
for i in range(1,n+1):
    num+=str(i)
num
# Out:
# '0.12345678910'

# %% [markdown]
# Good! Now write a function which returns final digit.
# Consider digits! Use while loops for it.

# %%
def dn(n):
    num = ""
    i = 1
    while len(num) < n:
        num += str(i)
        i += 1
    return int(num[n-1])

# %% [markdown]
# Now solve the problem

# %%
dn(1)*dn(10)*dn(100)*dn(1000)*dn(10000)*dn(100000)*dn(1000000)
# Out:
# 210
