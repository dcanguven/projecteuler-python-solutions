# %% [markdown]
# ![image.png](attachment:ca120285-b522-403c-b655-778df8cfaec3.png)

# %% [markdown]
# ## Notes
#
# Investigated several dynamic programming and matrix exponentiation approaches.
#
# The correct recurrence still needs to be derived before implementing the final solution.
