# %% [markdown]
# ![image.png](attachment:db275c37-34c0-4217-bf96-cd5a4b2a8274.png)

# %% [markdown]
# ## Initial approach

# %% [markdown]
# * Lets try it directly to understand the challange

# %% [markdown]
# * it didn't work.
# * it throws error message:
#
# ```python
# str(28433*2**7830457+1)[-5:]
#
# ---------------------------------------------------------------------------
# ValueError
# Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 str(28433*2**7830457+1)[-5:]
#
# ValueError: Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit
# ````

# %% [markdown]
# ## New approch

# %% [markdown]
# * use mod 10**5 to calculate just last 5 digits
# * use pow function for faster calculation

# %%
# %%time
print("Result:", str((28433 * pow(2, 7830457, 10**5) + 1))[-5:])
# Out:
# Result: 92577
# CPU times: user 134 μs, sys: 26 μs, total: 160 μs
# Wall time: 161 μs
