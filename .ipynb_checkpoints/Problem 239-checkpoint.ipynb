# %% [markdown]
# ![image.png](attachment:1821302b-b27f-4d69-8623-7a981c21c520.png)

# %% [markdown]
# ## Initial approach

# %%
Twenty-two Foolish Primes
Show HTML problem content 
Problem 239
A set of disks numbered  through  are placed in a line in random order.

What is the probability that we have a partial derangement such that exactly  prime number discs are found away from their natural positions?
(Any number of non-prime disks may also be found in or out of their natural positions.)

Give your answer rounded to  places behind the decimal point in the form 0.abcdefghijkl.
