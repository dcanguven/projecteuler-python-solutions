# %% [markdown]
# ![image.png](attachment:db55945f-f444-4c77-aa72-649c5251f094.png)

# %% [markdown]
# ## Initial approach

# %% [markdown]
# * restate the geometry clearly, fixed points O and C, variable integer point B inside the diamond |x|+|y| ≤ r
# * translate “largest angle is obtuse” into dot product inequalities at O, at C, and at B
# * treat the three obtuse cases separately so each one becomes a clean counting problem
# * notice that obtuse at O and obtuse at C reduce to simple half plane conditions on x+y
# * rewrite the obtuse at B condition into a quadratic inequality and complete the square to see a shifted circle
# * focus on counting lattice points efficiently using symmetry and line by line aggregation instead of brute force
# * keep all reasoning symbolic in r so the final step is just plugging in r = 10^9

# %%
# planned to revisit later by deriving each count carefully and combining them without overlap
