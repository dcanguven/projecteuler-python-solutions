# %% [markdown]
# ![image.png](attachment:876cf0e2-1951-41ff-b973-8955c5a8aeec.png)

# %% [markdown]
# ## Initial approach

# %% [markdown]
# Modular Cubes, Part 2
# Show HTML problem content
# Problem 272
# For a positive number , define  as the number of the integers , for which    and
#  .
#
# When  , there are  possible values for , namely: .
# Thus,  .
#
# Find the sum of the positive numbers   for which  .

# %%
# %%time
result = solve()
print("Result:", result)
# Out:
# Result: 785478606870985
# CPU times: user 2.8 s, sys: 4.1 ms, total: 2.81 s
# Wall time: 2.81 s
