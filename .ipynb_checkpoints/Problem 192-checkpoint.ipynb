# %% [markdown]
# ![image.png](attachment:06211f7e-d50d-468b-b4c6-f7c2d16788c7.png)

# %% [markdown]
# ## Initial approach

# %% [markdown]
# - the problem is tricky because it needs continued fractions to get best rational approximations
# - the search space is large since we must process all non square n up to 100000
# - naive checking of all denominators up to 10^12 is impossible so we must use number theory shortcuts
# - the solution depends on understanding convergents and when they give optimal fractions
#
# to be studied
