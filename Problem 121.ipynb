# %% [markdown]
# ![image.png](attachment:385ea683-975f-403c-bbc6-7a32b337512a.png)

# %% [markdown]
# ## Initial approach

# %% [markdown]
# * n turns
# * each turn bag has 1 blue dist + turn number red discs
# *
