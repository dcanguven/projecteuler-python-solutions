# %% [markdown]
# ![image.png](attachment:a5a9ede7-3cf5-48fb-b1df-54c8a5491cdd.png)

# %% [markdown]
# ## Initial approach

# %% [markdown]
# * traditional approach would take too long
# * define a function to check pandigital

# %%
def is_pandigital_1_to_9(n):
    return set(str(n)) == set("123456789")

# %% [markdown]
# * start a fibonacci sequence
#
# To check pandigital:
# * use % 10**9 to keep only the last 9 digits
# * use log10 math to get first 9 digits without storing whole number
#
# And...
# * if both pandigital, print the position and stop.

# %%
import math



a, b = 1, 1
a_last, b_last = 1, 1
index = 2

while True:
    a, b = b, a + b
    a_last, b_last = b_last, (a_last + b_last) % 10**9
    index += 1
    
    if is_pandigital_1_to_9(b_last):
        first9 = int(str(int(10**(math.log10(b) - int(math.log10(b)) + 8))))
        if is_pandigital_1_to_9(first9):
            print("Result:", index)
            break
# Out:
# Result: 329468
