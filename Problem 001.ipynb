# %% [markdown]
# ![image.png](attachment:7a283f5e-36f0-4cdd-8b47-ed5aee38bcd9.png)

# %% [markdown]
# ## Initial approach

# %%
# %%time

total = 0
for i in range(1,1000):
    if i%3==0:
        total+=i
    elif i%5==0:
        total+=i
print(total)
# Out:
# 233168
# CPU times: user 608 μs, sys: 75 μs, total: 683 μs
# Wall time: 707 μs

# %% [markdown]
# ## Clean and tested code

# %%
# %%time

total = sum(i for i in range(1, 1000) if i % 3 == 0 or i % 5 == 0)
print(total)
# Out:
# 233168
# CPU times: user 277 μs, sys: 55 μs, total: 332 μs
# Wall time: 311 μs
