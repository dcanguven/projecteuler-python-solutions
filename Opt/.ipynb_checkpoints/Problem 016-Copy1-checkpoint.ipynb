# %% [markdown]
# ![image.png](attachment:3f921b6b-51eb-4353-8681-116fe958bcda.png)

# %% [markdown]
# ## Initial approach

# %%
# %%time

num = str(pow(2,1000))
total = 0
for i in num:
    total += int(i)
print(total)
# Out:
# 1366
# CPU times: user 188 μs, sys: 11 μs, total: 199 μs
# Wall time: 196 μs

# %% [markdown]
# ## Clean and tested code

# %%
# %%time

total = sum(int(digit) for digit in str(2**1000))
print(total)
# Out:
# 1366
# CPU times: user 104 μs, sys: 5 μs, total: 109 μs
# Wall time: 110 μs
