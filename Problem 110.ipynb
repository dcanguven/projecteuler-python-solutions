# %% [markdown]
# ![image.png](attachment:2a3aa4e8-d01c-4a7f-a589-f0a69dea5e82.png)

# %% [markdown]
# ## Initial approach

# %% [markdown]
# ```python
# target = 4_000_000
# limit = 10**7
# n = 1
#
# while True:
#     list_of_solutions = set()
#     for x in range(1, limit):
#         for y in range(1, limit):
#             num = x * y
#             den = x + y
#             if den != 0 and num % den == 0:
#                 n_calc = num // den
#                 if n_calc == n:
#                     pair = tuple(sorted((x, y)))
#                     if pair not in list_of_solutions:
#                         list_of_solutions.add(pair)
#                         if len(list_of_solutions) > target:
#                             print(n)
#                             exit()
# ````

# %% [markdown]
# * same issue with problem 108.
# * even though this would be an answer, it would take forever to run.
# * I need to optimize it sometime.
