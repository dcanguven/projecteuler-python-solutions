# %% [markdown]
# ![image.png](attachment:2053cd67-8551-4a37-ae2c-73e98faf37d0.png)

# %% [markdown]
# ## Initial approach

# %% [markdown]
# * if n is even --> r mod a^2 is always 2
# * if n is odd --> r is 2na mod a^2
# * the biggest remainder = a^2 - a
# * answer = sum of (a^2 - a) for a = 3 to 1000

# %%
total = 0

for a in range(3, 1001):
    r_max = a * a - a
    total += r_max

print("Result:", total)
# Out:
# Result: 333332998
